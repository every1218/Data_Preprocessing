# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Weather_BigData/habit_kor.csv',encoding='euc-kr')

df.head()
# Out:
#     학생ID  나이      성별  하루공부시간  SNS사용시간  넷플릭스시청시간 아르바이트여부   출석률  수면시간 식습관상태  \
# 0  S1000  23  Female     0.0      1.2       1.1      No  85.0   8.0  Fair
# 1  S1001  20  Female     6.9      2.8       2.3      No  97.3   4.6  Good
# 2  S1002  21    Male     1.4      3.1       1.3      No  94.8   8.0  Poor
# 3  S1003  23  Female     1.0      3.9       1.0      No  71.0   9.2  Poor
# 4  S1004  19  Female     5.0      4.4       0.5      No  90.9   4.9  Fair
#
#    운동빈도       부모교육수준    인터넷품질  정신건강점수 과외활동참여여부   시험점수
# 0     6       Master  Average       8      Yes   56.2
# 1     6  High School  Average       8       No  100.0
# 2     1  High School     Poor       1       No   34.3
# 3     4       Master     Good       1      Yes   26.8
# 4     3       Master     Good       1       No   66.4

# %%
#1
df.groupby('성별')['시험점수'].mean()


#2
df[df['하루공부시간']>=6]['운동빈도'].mean()

#3
df.groupby('아르바이트여부')['수면시간'].mean()
df.groupby('아르바이트여부')['시험점수'].mean()
df.groupby('아르바이트여부')['SNS사용시간'].mean()


#4
df.groupby('나이').count()

#5
df.groupby('성별')['시험점수'].count()

# %%
#1
df[df['시험점수']>=80].groupby('성별')['SNS사용시간'].mean()

#2 답지봄 틀린거로 처리해줘
df =df.sort_values('하루공부시간',ascending=False).reset_index(drop=True)
df[['학생ID', '하루공부시간','시험점수']].head(5)

#3
df.groupby('아르바이트여부')[['출석률','정신건강점수']].mean()

#4 틀린거처리
df.pivot_table(index='부모교육수준',values='시험점수',aggfunc='mean')

#5
df[df['식습관상태']=='Good'][['수면시간','운동빈도']].mean()
# Out:
# 수면시간    6.432011
# 운동빈도    3.105820
# dtype: float64
